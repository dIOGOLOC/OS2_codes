# %% [markdown]
# # Pacotes & Configurações:

# %% [markdown]
# ## Para fazer com que o Jupyter Notebook exiba as figuras diretamente nas células:

# %%
# %matplotlib inline

# %% [markdown]
# ## Importação de pacotes nativos do python

# %%
from time import time

from os import path

import pandas as pd

import numpy as np

from ipywidgets import interactive

import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1.inset_locator import inset_axes

from scipy.signal import butter, filtfilt

# %% [markdown]
# ## Importação de pacotes que necessitam de instalação

# %%
# segysak (https://trhallam.github.io/segysak/latest/)
# pip install segysak
from segysak.segy import get_segy_texthead, segy_header_scan, segy_header_scrape

# xarray (https://docs.xarray.dev/en/stable/)
# pip install xarray
import xarray as xr

# Cartopy (https://scitools.org.uk/cartopy/docs/latest/)
# pip install cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.geoaxes import GeoAxes

# pyproj
# pip install pyproj
import pyproj

# %% [markdown]
# # Pacote principal
#
# # segysak
# - https://trhallam.github.io/segysak/latest/index.html
# <img src="attachment:593ca9c0-b096-4417-a6d5-2021b8236f5a.png" width="400" height="200">
#
# ### Tutorial:
# - https://trhallam.github.io/segysak/latest/tutorial.html

# %% [markdown]
# ## Passos para a leitura do arquivo de sísmica 2D (SEGY):
# **1. Checar se existe o arquivo:**

# %%
segy_file = "/home/enseadamartel/Documents/OS2_dIOGO_2025/01_dados_brutos/Dados_teste_SEGY/segy/247_Santos_part2a.sgy"
print("Aquivo sísmica 2D:", segy_file,"\nExiste:",path.exists(segy_file))
# Out:
# Aquivo sísmica 2D: /home/enseadamartel/Documents/OS2_dIOGO_2025/01_dados_brutos/Dados_teste_SEGY/segy/247_Santos_part2a.sgy
# Existe: True

# %% [markdown]
# **2. Ler o cabeçalho (header) e checar a localização dos bytes via segy_header_scan:**
# - https://trhallam.github.io/segysak/latest/api/segy_inspecting.html#segysak.segy.segy_bin_scrape

# %%
scan = segy_header_scan(segy_file,max_traces_scan=200000)

with pd.option_context("display.max_rows", 100, "display.max_columns", 10):
    # drop byte locations where the mean is zero, these are likely empty.
    display(scan)
# Out:
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/32.0k [00:00<?, ? traces/s]
#                                         byte_loc     count          mean  \
# TRACE_SEQUENCE_LINE                            1  131978.0  65989.500000
# TRACE_SEQUENCE_FILE                            5  131978.0  65989.500000
# FieldRecord                                    9  131978.0    436.389732
# TraceNumber                                   13  131978.0     73.564935
# EnergySourcePoint                             17  131978.0      0.000000
# CDP                                           21  131978.0      0.000000
# CDP_TRACE                                     25  131978.0      0.000000
# TraceIdentificationCode                       29  131978.0      1.000000
# NSummedTraces                                 31  131978.0      0.000000
# NStackedTraces                                33  131978.0      0.000000
# DataUse                                       35  131978.0      0.000000
# offset                                        37  131978.0      0.000000
# ReceiverGroupElevation                        41  131978.0      0.000000
# SourceSurfaceElevation                        45  131978.0      0.000000
# SourceDepth                                   49  131978.0      0.000000
# ReceiverDatumElevation                        53  131978.0      0.000000
# SourceDatumElevation                          57  131978.0      0.000000
# SourceWaterDepth                              61  131978.0      0.000000
# GroupWaterDepth                               65  131978.0      0.000000
# ElevationScalar                               69  131978.0    -10.000000
# SourceGroupScalar                             71  131978.0    -10.000000
# SourceX                                       73  131978.0      0.000000
# SourceY                                       77  131978.0      0.000000
# GroupX                                        81  131978.0      0.000000
# GroupY                                        85  131978.0      0.000000
# CoordinateUnits                               89  131978.0      0.000000
# WeatheringVelocity                            91  131978.0      0.000000
# SubWeatheringVelocity                         93  131978.0      0.000000
# SourceUpholeTime                              95  131978.0      0.000000
# GroupUpholeTime                               97  131978.0      0.000000
# SourceStaticCorrection                        99  131978.0      0.000000
# GroupStaticCorrection                        101  131978.0      0.000000
# TotalStaticApplied                           103  131978.0      0.000000
# LagTimeA                                     105  131978.0      0.000000
# LagTimeB                                     107  131978.0      0.000000
# DelayRecordingTime                           109  131978.0      0.000000
# MuteTimeStart                                111  131978.0      0.000000
# MuteTimeEND                                  113  131978.0      0.000000
# TRACE_SAMPLE_COUNT                           115  131978.0   2501.000000
# TRACE_SAMPLE_INTERVAL                        117  131978.0   2000.000000
# GainType                                     119  131978.0      0.000000
# InstrumentGainConstant                       121  131978.0      0.000000
# InstrumentInitialGain                        123  131978.0      0.000000
# Correlated                                   125  131978.0      0.000000
# SweepFrequencyStart                          127  131978.0      0.000000
# SweepFrequencyEnd                            129  131978.0      0.000000
# SweepLength                                  131  131978.0      0.000000
# SweepType                                    133  131978.0      0.000000
# SweepTraceTaperLengthStart                   135  131978.0      0.000000
# SweepTraceTaperLengthEnd                     137  131978.0      0.000000
# TaperType                                    139  131978.0      0.000000
# AliasFilterFrequency                         141  131978.0      0.000000
# AliasFilterSlope                             143  131978.0      0.000000
# NotchFilterFrequency                         145  131978.0      0.000000
# NotchFilterSlope                             147  131978.0      0.000000
# LowCutFrequency                              149  131978.0      0.000000
# HighCutFrequency                             151  131978.0      0.000000
# LowCutSlope                                  153  131978.0      0.000000
# HighCutSlope                                 155  131978.0      0.000000
# YearDataRecorded                             157  131978.0     85.000000
# DayOfYear                                    159  131978.0    206.793466
# HourOfDay                                    161  131978.0      5.135356
# MinuteOfHour                                 163  131978.0     31.968495
# SecondOfMinute                               165  131978.0     29.173862
# TimeBaseCode                                 167  131978.0      0.000000
# TraceWeightingFactor                         169  131978.0      0.000000
# GeophoneGroupNumberRoll1                     171  131978.0      0.000000
# GeophoneGroupNumberFirstTraceOrigField       173  131978.0      0.000000
# GeophoneGroupNumberLastTraceOrigField        175  131978.0      0.000000
# GapSize                                      177  131978.0      0.000000
# OverTravel                                   179  131978.0      0.000000
# CDP_X                                        181  131978.0    436.389732
# CDP_Y                                        185  131978.0     73.564935
# INLINE_3D                                    189  131978.0      0.000000
# CROSSLINE_3D                                 193  131978.0      0.000000
# ShotPoint                                    197  131978.0      0.000000
# ShotPointScalar                              201  131978.0      0.000000
# TraceValueMeasurementUnit                    203  131978.0      0.000000
# TransductionConstantMantissa                 205  131978.0      0.000000
# TransductionConstantPower                    209  131978.0      0.000000
# TransductionUnit                             211  131978.0      0.000000
# TraceIdentifier                              213  131978.0      0.000000
# ScalarTraceHeader                            215  131978.0      0.000000
# SourceType                                   217  131978.0      1.662338
# SourceEnergyDirectionMantissa                219  131978.0      0.000000
# SourceEnergyDirectionExponent                223  131978.0      0.000000
# SourceMeasurementMantissa                    225  131978.0      0.000000
# SourceMeasurementExponent                    229  131978.0      0.000000
# SourceMeasurementUnit                        231  131978.0      0.000000
# UnassignedInt1                               233  131978.0      0.000000
# UnassignedInt2                               237  131978.0      0.000000
#
#                                                  std     min       25%  \
# TRACE_SEQUENCE_LINE                     38098.911251     1.0  32995.25
# TRACE_SEQUENCE_FILE                     38098.911251     1.0  32995.25
# FieldRecord                               248.688526     7.0    221.00
# TraceNumber                                44.346931     1.0     35.00
# EnergySourcePoint                           0.000000     0.0      0.00
# CDP                                         0.000000     0.0      0.00
# CDP_TRACE                                   0.000000     0.0      0.00
# TraceIdentificationCode                     0.558293    -1.0      1.00
# NSummedTraces                               0.000000     0.0      0.00
# NStackedTraces                              0.000000     0.0      0.00
# DataUse                                     0.000000     0.0      0.00
# offset                                      0.000000     0.0      0.00
# ReceiverGroupElevation                      0.000000     0.0      0.00
# SourceSurfaceElevation                      0.000000     0.0      0.00
# SourceDepth                                 0.000000     0.0      0.00
# ReceiverDatumElevation                      0.000000     0.0      0.00
# SourceDatumElevation                        0.000000     0.0      0.00
# SourceWaterDepth                            0.000000     0.0      0.00
# GroupWaterDepth                             0.000000     0.0      0.00
# ElevationScalar                             0.000000   -10.0    -10.00
# SourceGroupScalar                           0.000000   -10.0    -10.00
# SourceX                                     0.000000     0.0      0.00
# SourceY                                     0.000000     0.0      0.00
# GroupX                                      0.000000     0.0      0.00
# GroupY                                      0.000000     0.0      0.00
# CoordinateUnits                             0.000000     0.0      0.00
# WeatheringVelocity                          0.000000     0.0      0.00
# SubWeatheringVelocity                       0.000000     0.0      0.00
# SourceUpholeTime                            0.000000     0.0      0.00
# GroupUpholeTime                             0.000000     0.0      0.00
# SourceStaticCorrection                      0.000000     0.0      0.00
# GroupStaticCorrection                       0.000000     0.0      0.00
# TotalStaticApplied                          0.000000     0.0      0.00
# LagTimeA                                    0.000000     0.0      0.00
# LagTimeB                                    0.000000     0.0      0.00
# DelayRecordingTime                          0.000000     0.0      0.00
# MuteTimeStart                               0.000000     0.0      0.00
# MuteTimeEND                                 0.000000     0.0      0.00
# TRACE_SAMPLE_COUNT                          0.000000  2501.0   2501.00
# TRACE_SAMPLE_INTERVAL                       0.000000  2000.0   2000.00
# GainType                                    0.000000     0.0      0.00
# InstrumentGainConstant                      0.000000     0.0      0.00
# InstrumentInitialGain                       0.000000     0.0      0.00
# Correlated                                  0.000000     0.0      0.00
# SweepFrequencyStart                         0.000000     0.0      0.00
# SweepFrequencyEnd                           0.000000     0.0      0.00
# SweepLength                                 0.000000     0.0      0.00
# SweepType                                   0.000000     0.0      0.00
# SweepTraceTaperLengthStart                  0.000000     0.0      0.00
# SweepTraceTaperLengthEnd                    0.000000     0.0      0.00
# TaperType                                   0.000000     0.0      0.00
# AliasFilterFrequency                        0.000000     0.0      0.00
# AliasFilterSlope                            0.000000     0.0      0.00
# NotchFilterFrequency                        0.000000     0.0      0.00
# NotchFilterSlope                            0.000000     0.0      0.00
# LowCutFrequency                             0.000000     0.0      0.00
# HighCutFrequency                            0.000000     0.0      0.00
# LowCutSlope                                 0.000000     0.0      0.00
# HighCutSlope                                0.000000     0.0      0.00
# YearDataRecorded                            0.000000    85.0     85.00
# DayOfYear                                   0.404820   206.0    207.00
# HourOfDay                                   9.125268     0.0      0.00
# MinuteOfHour                               16.941454     0.0     18.00
# SecondOfMinute                             17.333944     0.0     14.00
# TimeBaseCode                                0.000000     0.0      0.00
# TraceWeightingFactor                        0.000000     0.0      0.00
# GeophoneGroupNumberRoll1                    0.000000     0.0      0.00
# GeophoneGroupNumberFirstTraceOrigField      0.000000     0.0      0.00
# GeophoneGroupNumberLastTraceOrigField       0.000000     0.0      0.00
# GapSize                                     0.000000     0.0      0.00
# OverTravel                                  0.000000     0.0      0.00
# CDP_X                                     248.688526     7.0    221.00
# CDP_Y                                      44.346931     1.0     35.00
# INLINE_3D                                   0.000000     0.0      0.00
# CROSSLINE_3D                                0.000000     0.0      0.00
# ShotPoint                                   0.000000     0.0      0.00
# ShotPointScalar                             0.000000     0.0      0.00
# TraceValueMeasurementUnit                   0.000000     0.0      0.00
# TransductionConstantMantissa                0.000000     0.0      0.00
# TransductionConstantPower                   0.000000     0.0      0.00
# TransductionUnit                            0.000000     0.0      0.00
# TraceIdentifier                             0.000000     0.0      0.00
# ScalarTraceHeader                           0.000000     0.0      0.00
# SourceType                                 20.562059     0.0      0.00
# SourceEnergyDirectionMantissa               0.000000     0.0      0.00
# SourceEnergyDirectionExponent               0.000000     0.0      0.00
# SourceMeasurementMantissa                   0.000000     0.0      0.00
# SourceMeasurementExponent                   0.000000     0.0      0.00
# SourceMeasurementUnit                       0.000000     0.0      0.00
# UnassignedInt1                              0.000000     0.0      0.00
# UnassignedInt2                              0.000000     0.0      0.00
#
#                                             50%       75%       max
# TRACE_SEQUENCE_LINE                     65989.5  98983.75  131978.0
# TRACE_SEQUENCE_FILE                     65989.5  98983.75  131978.0
# FieldRecord                               435.0    652.00     866.0
# TraceNumber                                73.5    112.00     150.0
# EnergySourcePoint                           0.0      0.00       0.0
# CDP                                         0.0      0.00       0.0
# CDP_TRACE                                   0.0      0.00       0.0
# TraceIdentificationCode                     1.0      1.00       7.0
# NSummedTraces                               0.0      0.00       0.0
# NStackedTraces                              0.0      0.00       0.0
# DataUse                                     0.0      0.00       0.0
# offset                                      0.0      0.00       0.0
# ReceiverGroupElevation                      0.0      0.00       0.0
# SourceSurfaceElevation                      0.0      0.00       0.0
# SourceDepth                                 0.0      0.00       0.0
# ReceiverDatumElevation                      0.0      0.00       0.0
# SourceDatumElevation                        0.0      0.00       0.0
# SourceWaterDepth                            0.0      0.00       0.0
# GroupWaterDepth                             0.0      0.00       0.0
# ElevationScalar                           -10.0    -10.00     -10.0
# SourceGroupScalar                         -10.0    -10.00     -10.0
# SourceX                                     0.0      0.00       0.0
# SourceY                                     0.0      0.00       0.0
# GroupX                                      0.0      0.00       0.0
# GroupY                                      0.0      0.00       0.0
# CoordinateUnits                             0.0      0.00       0.0
# WeatheringVelocity                          0.0      0.00       0.0
# SubWeatheringVelocity                       0.0      0.00       0.0
# SourceUpholeTime                            0.0      0.00       0.0
# GroupUpholeTime                             0.0      0.00       0.0
# SourceStaticCorrection                      0.0      0.00       0.0
# GroupStaticCorrection                       0.0      0.00       0.0
# TotalStaticApplied                          0.0      0.00       0.0
# LagTimeA                                    0.0      0.00       0.0
# LagTimeB                                    0.0      0.00       0.0
# DelayRecordingTime                          0.0      0.00       0.0
# MuteTimeStart                               0.0      0.00       0.0
# MuteTimeEND                                 0.0      0.00       0.0
# TRACE_SAMPLE_COUNT                       2501.0   2501.00    2501.0
# TRACE_SAMPLE_INTERVAL                    2000.0   2000.00    2000.0
# GainType                                    0.0      0.00       0.0
# InstrumentGainConstant                      0.0      0.00       0.0
# InstrumentInitialGain                       0.0      0.00       0.0
# Correlated                                  0.0      0.00       0.0
# SweepFrequencyStart                         0.0      0.00       0.0
# SweepFrequencyEnd                           0.0      0.00       0.0
# SweepLength                                 0.0      0.00       0.0
# SweepType                                   0.0      0.00       0.0
# SweepTraceTaperLengthStart                  0.0      0.00       0.0
# SweepTraceTaperLengthEnd                    0.0      0.00       0.0
# TaperType                                   0.0      0.00       0.0
# AliasFilterFrequency                        0.0      0.00       0.0
# AliasFilterSlope                            0.0      0.00       0.0
# NotchFilterFrequency                        0.0      0.00       0.0
# NotchFilterSlope                            0.0      0.00       0.0
# LowCutFrequency                             0.0      0.00       0.0
# HighCutFrequency                            0.0      0.00       0.0
# LowCutSlope                                 0.0      0.00       0.0
# HighCutSlope                                0.0      0.00       0.0
# YearDataRecorded                           85.0     85.00      85.0
# DayOfYear                                 207.0    207.00     207.0
# HourOfDay                                   1.0      1.00      23.0
# MinuteOfHour                               34.0     46.00      59.0
# SecondOfMinute                             30.0     44.00      59.0
# TimeBaseCode                                0.0      0.00       0.0
# TraceWeightingFactor                        0.0      0.00       0.0
# GeophoneGroupNumberRoll1                    0.0      0.00       0.0
# GeophoneGroupNumberFirstTraceOrigField      0.0      0.00       0.0
# GeophoneGroupNumberLastTraceOrigField       0.0      0.00       0.0
# GapSize                                     0.0      0.00       0.0
# OverTravel                                  0.0      0.00       0.0
# CDP_X                                     435.0    652.00     866.0
# CDP_Y                                      73.5    112.00     150.0
# INLINE_3D                                   0.0      0.00       0.0
# CROSSLINE_3D                                0.0      0.00       0.0
# ShotPoint                                   0.0      0.00       0.0
# ShotPointScalar                             0.0      0.00       0.0
# TraceValueMeasurementUnit                   0.0      0.00       0.0
# TransductionConstantMantissa                0.0      0.00       0.0
# TransductionConstantPower                   0.0      0.00       0.0
# TransductionUnit                            0.0      0.00       0.0
# TraceIdentifier                             0.0      0.00       0.0
# ScalarTraceHeader                           0.0      0.00       0.0
# SourceType                                  0.0      0.00     256.0
# SourceEnergyDirectionMantissa               0.0      0.00       0.0
# SourceEnergyDirectionExponent               0.0      0.00       0.0
# SourceMeasurementMantissa                   0.0      0.00       0.0
# SourceMeasurementExponent                   0.0      0.00       0.0
# SourceMeasurementUnit                       0.0      0.00       0.0
# UnassignedInt1                              0.0      0.00       0.0
# UnassignedInt2                              0.0      0.00       0.0

# %% [markdown]
# **3. Acessar, armazenar e graficar os dados do cabeçalho (header) via segy_header_scrape:**
# - https://trhallam.github.io/segysak/latest/api/segy_inspecting.html#segysak.segy.segy_header_scrape
# - Transforma a saída dos dados em um objeto chamado **scrape**

# %%
scrape = segy_header_scrape(segy_file, partial_scan=None)
# Out:
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/32.0k [00:00<?, ? traces/s]

# %%
scrape.columns
# Out:
# Index(['TRACE_SEQUENCE_LINE', 'TRACE_SEQUENCE_FILE', 'FieldRecord',
#        'TraceNumber', 'EnergySourcePoint', 'CDP', 'CDP_TRACE',
#        'TraceIdentificationCode', 'NSummedTraces', 'NStackedTraces', 'DataUse',
#        'offset', 'ReceiverGroupElevation', 'SourceSurfaceElevation',
#        'SourceDepth', 'ReceiverDatumElevation', 'SourceDatumElevation',
#        'SourceWaterDepth', 'GroupWaterDepth', 'ElevationScalar',
#        'SourceGroupScalar', 'SourceX', 'SourceY', 'GroupX', 'GroupY',
#        'CoordinateUnits', 'WeatheringVelocity', 'SubWeatheringVelocity',
#        'SourceUpholeTime', 'GroupUpholeTime', 'SourceStaticCorrection',
#        'GroupStaticCorrection', 'TotalStaticApplied', 'LagTimeA', 'LagTimeB',
#        'DelayRecordingTime', 'MuteTimeStart', 'MuteTimeEND',
#        'TRACE_SAMPLE_COUNT', 'TRACE_SAMPLE_INTERVAL', 'GainType',
#        'InstrumentGainConstant', 'InstrumentInitialGain', 'Correlated',
#        'SweepFrequencyStart', 'SweepFrequencyEnd', 'SweepLength', 'SweepType',
#        'SweepTraceTaperLengthStart', 'SweepTraceTaperLengthEnd', 'TaperType',
#        'AliasFilterFrequency', 'AliasFilterSlope', 'NotchFilterFrequency',
#        'NotchFilterSlope', 'LowCutFrequency', 'HighCutFrequency',
#        'LowCutSlope', 'HighCutSlope', 'YearDataRecorded', 'DayOfYear',
#        'HourOfDay', 'MinuteOfHour', 'SecondOfMinute', 'TimeBaseCode',
#        'TraceWeightingFactor', 'GeophoneGroupNumberRoll1',
#        'GeophoneGroupNumberFirstTraceOrigField',
#        'GeophoneGroupNumberLastTraceOrigField', 'GapSize', 'OverTravel',
#        'CDP_X', 'CDP_Y', 'INLINE_3D', 'CROSSLINE_3D', 'ShotPoint',
#        'ShotPointScalar', 'TraceValueMeasurementUnit',
#        'TransductionConstantMantissa', 'TransductionConstantPower',
#        'TransductionUnit', 'TraceIdentifier', 'ScalarTraceHeader',
#        'SourceType', 'SourceEnergyDirectionMantissa',
#        'SourceEnergyDirectionExponent', 'SourceMeasurementMantissa',
#        'SourceMeasurementExponent', 'SourceMeasurementUnit', 'UnassignedInt1',
#        'UnassignedInt2'],
#       dtype='object')

# %%
plot = scrape.hist(bins=25, figsize=(20, 20))
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=2, figsize=(12, 10), sharex=True, sharey=True)

scrape.plot(
    kind="scatter", x="CDP_X", y="CDP_Y", c="TRACE_SEQUENCE_FILE", ax=axs[0], cmap="gist_ncar"
)
scrape.plot(
    kind="scatter", x="CDP_X", y="CDP_Y", c="TraceNumber", ax=axs[1], cmap="gist_ncar"
)
for aa in axs:
    aa.set_aspect("equal", "box")
plt.show()

# %%
fig, axs = plt.subplots(nrows=2, figsize=(12, 10), sharex=True, sharey=True)

scrape.plot(
    kind="scatter", x="CDP_X", y="CDP_Y", c="HourOfDay", ax=axs[0], cmap="gist_ncar"
)
scrape.plot(
    kind="scatter", x="CDP_X", y="CDP_Y", c="MinuteOfHour", ax=axs[1], cmap="gist_ncar"
)
for aa in axs:
    aa.set_aspect("equal", "box")
plt.show()

# %% [markdown]
# **4. Ler os dados SEG-Y via xarray open_dataset:**
# - https://trhallam.github.io/segysak/latest/examples/example_segysak_segy_vectorisation.html
# - https://docs.xarray.dev/en/stable/generated/xarray.open_dataset.html
# - Usar o **TRACE_SEQUENCE_FILE (?CDP?)**
#   -  Localização do byte:	5

# %%
ds = xr.open_dataset(segy_file, dim_byte_fields={'cdp': 5})
# Out:
# Processing Chunks:   0%|          | 0.00/2.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/100k [00:00<?, ? traces/s]
# Reading header:   0%|          | 0.00/32.0k [00:00<?, ? traces/s]

# %%
ds.keys()
# Out:
# KeysView(<xarray.Dataset> Size: 1GB
# Dimensions:  (cdp: 131978, samples: 2501)
# Coordinates:
#   * cdp      (cdp) int32 528kB 1 2 3 4 5 ... 131974 131975 131976 131977 131978
#   * samples  (samples) float32 10kB 0.0 2.0 4.0 ... 4.996e+03 4.998e+03 5e+03
# Data variables:
#     data     (cdp, samples) float32 1GB ...
# Attributes:
#     seisnc:   {"coord_scalar": -10.0, "coord_scaled": false})

# %% [markdown]
# ----
#
# **5. Graficar os dados SEG-Y via xarray:**
# - https://docs.xarray.dev/en/latest/user-guide/plotting.html
#
# ou
#
#
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
tiro_1 = ds.isel(cdp=slice(75460, 75610))

# %%
# Normalização dos dados 
normalized = tiro_1 / np.abs(tiro_1).max(dim='samples')

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each trace (wiggle plot style)
for i, cdp_val in enumerate(tiro_1.cdp.values):
    trace = normalized.sel(cdp=cdp_val)
    ax.plot(trace.data + i, tiro_1.samples, color='black', linewidth=0.5)

# Set Y-axis (samples)
ax.invert_yaxis()
ax.set_ylabel("Tempo (ms)")

# Set X-axis (cdp index)
ax.set_xlabel("Traços (id)")
ax.set_xticks(np.arange(0, len(tiro_1.cdp), 10))
ax.set_xticklabels(tiro_1.cdp.values[::10])

ax.set_title("Dados normalizados pela amplitude (Wiggle Plot)")
plt.tight_layout()
plt.show()

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each trace (wiggle plot style)
for i, cdp_val in enumerate(tiro_1.cdp.values):
    trace = tiro_1.sel(cdp=cdp_val)
    ax.plot(trace.data + i, tiro_1.samples, color='black', linewidth=0.5)

# Set Y-axis (samples)
ax.invert_yaxis()
ax.set_ylabel("Tempo (ms)")

# Set X-axis (cdp index)
ax.set_xlabel("Traços (id)")
ax.set_xticks(np.arange(0, len(tiro_1.cdp), 10))
ax.set_xticklabels(tiro_1.cdp.values[::10])
ax.set_aspect('auto')
ax.set_title("Dados não-normalizados (Wiggle Plot)")
plt.tight_layout()
plt.show()

# %%
# Dados normalizados interpolados

amplitude = tiro_1.transpose('samples', 'cdp').data

# Criar figura
fig, ax = plt.subplots(figsize=(10, 6))

# Exibir imagem com imshow
im = ax.imshow(
    amplitude,                     # dados
    aspect='auto',                 # não distorce eixos
    cmap='gray',                   # colormap para estilo sísmico
    extent=[
        tiro_1.cdp.min(), tiro_1.cdp.max(), 
        tiro_1.samples.max(), tiro_1.samples.min()
    ]
)

# Ajuste de eixos
ax.set_xlabel("Traço (id)")
ax.set_ylabel("Tempo (ms)")
ax.set_title("Dados normalizados pela amplitude (Interpolação)")

plt.colorbar(im, ax=ax, label='Amplitude')
plt.tight_layout()
plt.show()

# %% [markdown]
# ----
#
# **6. Filtragem dos dados SEG-Y via xarray.apply_ufunc:**
# - https://docs.xarray.dev/en/stable/generated/xarray.apply_ufunc.html

# %%
def bandpass_filter(trace, fs, lowcut, highcut, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, trace)

# %%
def filter_dataset_bandpass_ufunc(ds, var="data", fs=250, lowcut=1, highcut=20, order=4):
    """
    Aplica filtro bandpass à variável `var` de um xarray.Dataset 3D (iline, xline, samples)
    sem remover dimensões. Retorna novo Dataset com variável filtrada.
    """
    da = ds[var]

    # Aplica o filtro ao longo da dimensão "samples"
    da_filtered = xr.apply_ufunc(
        bandpass_filter,
        da,
        input_core_dims=[["samples"]],
        output_core_dims=[["samples"]],
        kwargs={"fs": fs, "lowcut": lowcut, "highcut": highcut, "order": order},
        vectorize=True,
        dask="allowed",
        output_dtypes=[da.dtype]
    )

    # Cria cópia do Dataset com a variável filtrada
    ds_filtered = ds.copy()
    ds_filtered[var] = da_filtered

    return ds_filtered

# %%
def f(lf, hf,t1,t2):
    
    tiro_1_filtered = filter_dataset_bandpass_ufunc(tiro_1, var="data", fs=250, lowcut=lf, highcut=hf)

    # Create figure and axis
    fig, (ax1,ax2) = plt.subplots(nrows= 1,ncols=2,figsize=(15, 5))
    
    # Normalização dos dados 
    normalized = tiro_1 / np.abs(tiro_1).max(dim='samples')
    
    # Plot each trace (wiggle plot style)
    for i, cdp_val in enumerate(tiro_1.cdp.values):
        trace = normalized.sel(cdp=cdp_val)
        ax1.plot(trace.data + i, tiro_1.samples, color='black', linewidth=0.5)
    
    # Set Y-axis (samples)
    ax1.invert_yaxis()
    ax1.set_ylabel("Tempo (ms)")
    ax1.set_ylim(t2,t1)
    
    # Set X-axis (cdp index)
    ax1.set_xlabel("Traços (id)")
    ax1.set_xticks(np.arange(0, len(tiro_1.cdp), 10))
    ax1.set_xticklabels(tiro_1.cdp.values[::10])
    
    ax1.set_title("Dados normalizados")
    
    # ----------------------------------------------------------------------------
    
    # Normalização dos dados 
    normalized = tiro_1_filtered / np.abs(tiro_1_filtered).max(dim='samples')
    
    # Plot each trace (wiggle plot style)
    for i, cdp_val in enumerate(tiro_1_filtered.cdp.values):
        trace = normalized.sel(cdp=cdp_val)
        ax2.plot(trace.data + i, tiro_1_filtered.samples, color='black', linewidth=0.5)
    
    # Set Y-axis (samples)
    ax2.invert_yaxis()
    ax2.set_ylim(t2,t1)
    
    # Set X-axis (cdp index)
    ax2.set_xlabel("Traços (id)")
    ax2.set_xticks(np.arange(0, len(tiro_1_filtered.cdp), 10))
    ax2.set_xticklabels(tiro_1_filtered.cdp.values[::10])
    
    ax2.set_title("Dados normalizados filtrados")
    
    
    plt.tight_layout()
    plt.show()
    
interactive_plot = interactive(f, lf=(5, 100), hf=(10, 124, 5),t2=(0,5000,100),t1=(0,5000,100))
output = interactive_plot.children[-1]
output.layout.height = '700px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=52, description='lf', min=5), IntSlider(value=65, description='hf', max=…

# %%
def f(lf, hf,t1,t2,apmlim):
    trace_val = 1
    trace = tiro_1.isel(cdp=trace_val)

    tiro_1_filtered = filter_dataset_bandpass_ufunc(tiro_1, var="data", fs=250, lowcut=lf, highcut=hf)

    trace_filtered = tiro_1_filtered.isel(cdp=trace_val)
    
    # Criando figura and eixos
    fig, (ax1,ax2,ax3) = plt.subplots(nrows= 1,ncols=3,figsize=(10, 6))
     
    # ===================================================
    # Traço bruto
    
    ax1.plot(trace.data, trace.samples, color='black', linewidth=0.5)
    
    # Set Y-axis (samples)
    ax1.invert_yaxis()
    ax1.set_ylim(t2,t1)
    ax1.set_xlim(-apmlim,apmlim)
    
    # Set X-axis (cdp index)
    ax1.set_xlabel("Amp ()")
    
    ax1.set_title('Bruto')
    
    # ===================================================
    # Traço normalizado
    
    ax2.plot(trace_filtered.data, trace_filtered.samples, color='black', linewidth=0.5)
    
    # Set Y-axis (samples)
    ax2.invert_yaxis()
    ax2.set_ylim(t2,t1)
    
    # Set X-axis (cdp index)
    ax2.set_xlabel("Amp ()")
    
    ax2.set_title('Filtrado - bp('+str(lf)+'-'+str(hf)+'Hz)')
    
    # ===================================================
    # Diferença entre os traços
    trace_diff = trace-trace_filtered
    
    ax3.plot(trace_diff.data, trace_diff.samples, color='black', linewidth=0.5)
    
    # Set Y-axis (samples)
    ax3.invert_yaxis()
    ax3.set_ylim(t2,t1)
    ax3.set_xlim(-apmlim,apmlim)
    
    # Set X-axis (cdp index)
    ax3.set_xlabel("Amp ()")
    
    ax3.set_title('Diferença')
    
    fig.suptitle('Traço - id: '+str(trace_val))
    plt.show()
    
interactive_plot = interactive(f, lf=(1, 100), hf=(1, 124, 5),t2=(0,5000,100),t1=(0,5000,100),apmlim=(10,300,10))
output = interactive_plot.children[-1]
output.layout.height = '700px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='lf', min=1), IntSlider(value=61, description='hf', max=…
