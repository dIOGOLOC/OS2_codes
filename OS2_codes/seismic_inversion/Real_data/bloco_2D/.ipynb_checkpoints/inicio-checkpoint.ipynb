# %%
# %matplotlib inline

# %%
from time import time

from os import path

import pandas as pd

import numpy as np

from ipywidgets import interactive

import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1.inset_locator import inset_axes

from scipy.signal import butter, filtfilt

#!pip install obspy

# %%
#segysak (https://trhallam.github.io/segysak/latest/)
#!pip install segysak
import segysak


from segysak.segy import get_segy_texthead, segy_header_scan, segy_header_scrape

#xarray (https://docs.xarray.dev/en/stable/)
#!pip install xarray
import xarray as xr

#Cartopy (https://scitools.org.uk/cartopy/docs/latest/)
#!pip install cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.geoaxes import GeoAxes

#pyproj
#!pip install pyproj
import pyproj

# %%
segy_file = "E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy"
print("Aquivo sísmica 2D:", segy_file,"\nExiste:",path.exists(segy_file))
# Out:
# Aquivo sísmica 2D: E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy
# Existe: True

# %%
from segysak.segy import segy_loader
segy_file

#segy_file = segy_loader("E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy")
#print(segy_file.shape)  # Verifica se carregou traços e amostras
#print(len(segy_file))   # Número de traços
# Out:
# 'E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy'

# %%
from segysak.segy import segy_header_scan
import pandas as pd

# Caminho do arquivo SEG-Y
file_path = "E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy"

# Agora sim, isso funciona
scan = segy_header_scan(file_path, max_traces_scan=60000)

# Exibe os headers
with pd.option_context("display.max_rows", 100, "display.max_columns", 10):
    display(scan)
# Out:
# Processing Chunks:   0%|          | 0.00/1.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/52.8k [00:00<?, ? traces/s]
#                                         byte_loc    count          mean  \
# TRACE_SEQUENCE_LINE                            1  52822.0  26411.500000
# TRACE_SEQUENCE_FILE                            5  52822.0  26411.500000
# FieldRecord                                    9  52822.0   1382.264511
# TraceNumber                                   13  52822.0     73.509201
# EnergySourcePoint                             17  52822.0      0.000000
# CDP                                           21  52822.0      0.000000
# CDP_TRACE                                     25  52822.0      0.000000
# TraceIdentificationCode                       29  52822.0      1.000000
# NSummedTraces                                 31  52822.0      0.000000
# NStackedTraces                                33  52822.0      0.000000
# DataUse                                       35  52822.0      0.000000
# offset                                        37  52822.0      0.000000
# ReceiverGroupElevation                        41  52822.0      0.000000
# SourceSurfaceElevation                        45  52822.0      0.000000
# SourceDepth                                   49  52822.0      0.000000
# ReceiverDatumElevation                        53  52822.0      0.000000
# SourceDatumElevation                          57  52822.0      0.000000
# SourceWaterDepth                              61  52822.0      0.000000
# GroupWaterDepth                               65  52822.0      0.000000
# ElevationScalar                               69  52822.0    -10.000000
# SourceGroupScalar                             71  52822.0    -10.000000
# SourceX                                       73  52822.0      0.000000
# SourceY                                       77  52822.0      0.000000
# GroupX                                        81  52822.0      0.000000
# GroupY                                        85  52822.0      0.000000
# CoordinateUnits                               89  52822.0      0.000000
# WeatheringVelocity                            91  52822.0      0.000000
# SubWeatheringVelocity                         93  52822.0      0.000000
# SourceUpholeTime                              95  52822.0      0.000000
# GroupUpholeTime                               97  52822.0      0.000000
# SourceStaticCorrection                        99  52822.0      0.000000
# GroupStaticCorrection                        101  52822.0      0.000000
# TotalStaticApplied                           103  52822.0      0.000000
# LagTimeA                                     105  52822.0      0.000000
# LagTimeB                                     107  52822.0      0.000000
# DelayRecordingTime                           109  52822.0      0.000000
# MuteTimeStart                                111  52822.0      0.000000
# MuteTimeEND                                  113  52822.0      0.000000
# TRACE_SAMPLE_COUNT                           115  52822.0   2501.000000
# TRACE_SAMPLE_INTERVAL                        117  52822.0   2000.000000
# GainType                                     119  52822.0      0.000000
# InstrumentGainConstant                       121  52822.0      0.000000
# InstrumentInitialGain                        123  52822.0      0.000000
# Correlated                                   125  52822.0      0.000000
# SweepFrequencyStart                          127  52822.0      0.000000
# SweepFrequencyEnd                            129  52822.0      0.000000
# SweepLength                                  131  52822.0      0.000000
# SweepType                                    133  52822.0      0.000000
# SweepTraceTaperLengthStart                   135  52822.0      0.000000
# SweepTraceTaperLengthEnd                     137  52822.0      0.000000
# TaperType                                    139  52822.0      0.000000
# AliasFilterFrequency                         141  52822.0      0.000000
# AliasFilterSlope                             143  52822.0      0.000000
# NotchFilterFrequency                         145  52822.0      0.000000
# NotchFilterSlope                             147  52822.0      0.000000
# LowCutFrequency                              149  52822.0      0.000000
# HighCutFrequency                             151  52822.0      0.000000
# LowCutSlope                                  153  52822.0      0.000000
# HighCutSlope                                 155  52822.0      0.000000
# YearDataRecorded                             157  52822.0     93.000000
# DayOfYear                                    159  52822.0     31.000000
# HourOfDay                                    161  52822.0      7.355685
# MinuteOfHour                                 163  52822.0     29.486880
# SecondOfMinute                               165  52822.0     29.720117
# TimeBaseCode                                 167  52822.0      0.000000
# TraceWeightingFactor                         169  52822.0      0.000000
# GeophoneGroupNumberRoll1                     171  52822.0      0.000000
# GeophoneGroupNumberFirstTraceOrigField       173  52822.0      0.000000
# GeophoneGroupNumberLastTraceOrigField        175  52822.0      0.000000
# GapSize                                      177  52822.0      0.000000
# OverTravel                                   179  52822.0      0.000000
# CDP_X                                        181  52822.0   1382.264511
# CDP_Y                                        185  52822.0     73.509201
# INLINE_3D                                    189  52822.0      0.000000
# CROSSLINE_3D                                 193  52822.0      0.000000
# ShotPoint                                    197  52822.0      0.000000
# ShotPointScalar                              201  52822.0      0.000000
# TraceValueMeasurementUnit                    203  52822.0      0.000000
# TransductionConstantMantissa                 205  52822.0      0.000000
# TransductionConstantPower                    209  52822.0      0.000000
# TransductionUnit                             211  52822.0      0.000000
# TraceIdentifier                              213  52822.0      0.000000
# ScalarTraceHeader                            215  52822.0      0.000000
# SourceType                                   217  52822.0      1.662338
# SourceEnergyDirectionMantissa                219  52822.0      0.000000
# SourceEnergyDirectionExponent                223  52822.0      0.000000
# SourceMeasurementMantissa                    225  52822.0      0.000000
# SourceMeasurementExponent                    229  52822.0      0.000000
# SourceMeasurementUnit                        231  52822.0      0.000000
# UnassignedInt1                               233  52822.0      0.000000
# UnassignedInt2                               237  52822.0      0.000000
#
#                                                  std     min       25%  \
# TRACE_SEQUENCE_LINE                     15248.542296     1.0  13206.25
# TRACE_SEQUENCE_FILE                     15248.542296     1.0  13206.25
# FieldRecord                               103.416992     0.0   1297.00
# TraceNumber                                44.351582     0.0     35.00
# EnergySourcePoint                           0.000000     0.0      0.00
# CDP                                         0.000000     0.0      0.00
# CDP_TRACE                                   0.000000     0.0      0.00
# TraceIdentificationCode                     0.558296    -1.0      1.00
# NSummedTraces                               0.000000     0.0      0.00
# NStackedTraces                              0.000000     0.0      0.00
# DataUse                                     0.000000     0.0      0.00
# offset                                      0.000000     0.0      0.00
# ReceiverGroupElevation                      0.000000     0.0      0.00
# SourceSurfaceElevation                      0.000000     0.0      0.00
# SourceDepth                                 0.000000     0.0      0.00
# ReceiverDatumElevation                      0.000000     0.0      0.00
# SourceDatumElevation                        0.000000     0.0      0.00
# SourceWaterDepth                            0.000000     0.0      0.00
# GroupWaterDepth                             0.000000     0.0      0.00
# ElevationScalar                             0.000000   -10.0    -10.00
# SourceGroupScalar                           0.000000   -10.0    -10.00
# SourceX                                     0.000000     0.0      0.00
# SourceY                                     0.000000     0.0      0.00
# GroupX                                      0.000000     0.0      0.00
# GroupY                                      0.000000     0.0      0.00
# CoordinateUnits                             0.000000     0.0      0.00
# WeatheringVelocity                          0.000000     0.0      0.00
# SubWeatheringVelocity                       0.000000     0.0      0.00
# SourceUpholeTime                            0.000000     0.0      0.00
# GroupUpholeTime                             0.000000     0.0      0.00
# SourceStaticCorrection                      0.000000     0.0      0.00
# GroupStaticCorrection                       0.000000     0.0      0.00
# TotalStaticApplied                          0.000000     0.0      0.00
# LagTimeA                                    0.000000     0.0      0.00
# LagTimeB                                    0.000000     0.0      0.00
# DelayRecordingTime                          0.000000     0.0      0.00
# MuteTimeStart                               0.000000     0.0      0.00
# MuteTimeEND                                 0.000000     0.0      0.00
# TRACE_SAMPLE_COUNT                          0.000000  2501.0   2501.00
# TRACE_SAMPLE_INTERVAL                       0.000000  2000.0   2000.00
# GainType                                    0.000000     0.0      0.00
# InstrumentGainConstant                      0.000000     0.0      0.00
# InstrumentInitialGain                       0.000000     0.0      0.00
# Correlated                                  0.000000     0.0      0.00
# SweepFrequencyStart                         0.000000     0.0      0.00
# SweepFrequencyEnd                           0.000000     0.0      0.00
# SweepLength                                 0.000000     0.0      0.00
# SweepType                                   0.000000     0.0      0.00
# SweepTraceTaperLengthStart                  0.000000     0.0      0.00
# SweepTraceTaperLengthEnd                    0.000000     0.0      0.00
# TaperType                                   0.000000     0.0      0.00
# AliasFilterFrequency                        0.000000     0.0      0.00
# AliasFilterSlope                            0.000000     0.0      0.00
# NotchFilterFrequency                        0.000000     0.0      0.00
# NotchFilterSlope                            0.000000     0.0      0.00
# LowCutFrequency                             0.000000     0.0      0.00
# HighCutFrequency                            0.000000     0.0      0.00
# LowCutSlope                                 0.000000     0.0      0.00
# HighCutSlope                                0.000000     0.0      0.00
# YearDataRecorded                            0.000000    93.0     93.00
# DayOfYear                                   0.000000    31.0     31.00
# HourOfDay                                   0.478725     7.0      7.00
# MinuteOfHour                               17.529624     0.0     14.00
# SecondOfMinute                             17.318916     0.0     14.00
# TimeBaseCode                                0.000000     0.0      0.00
# TraceWeightingFactor                        0.000000     0.0      0.00
# GeophoneGroupNumberRoll1                    0.000000     0.0      0.00
# GeophoneGroupNumberFirstTraceOrigField      0.000000     0.0      0.00
# GeophoneGroupNumberLastTraceOrigField       0.000000     0.0      0.00
# GapSize                                     0.000000     0.0      0.00
# OverTravel                                  0.000000     0.0      0.00
# CDP_X                                     103.416992     0.0   1297.00
# CDP_Y                                      44.351582     0.0     35.00
# INLINE_3D                                   0.000000     0.0      0.00
# CROSSLINE_3D                                0.000000     0.0      0.00
# ShotPoint                                   0.000000     0.0      0.00
# ShotPointScalar                             0.000000     0.0      0.00
# TraceValueMeasurementUnit                   0.000000     0.0      0.00
# TransductionConstantMantissa                0.000000     0.0      0.00
# TransductionConstantPower                   0.000000     0.0      0.00
# TransductionUnit                            0.000000     0.0      0.00
# TraceIdentifier                             0.000000     0.0      0.00
# ScalarTraceHeader                           0.000000     0.0      0.00
# SourceType                                 20.562176     0.0      0.00
# SourceEnergyDirectionMantissa               0.000000     0.0      0.00
# SourceEnergyDirectionExponent               0.000000     0.0      0.00
# SourceMeasurementMantissa                   0.000000     0.0      0.00
# SourceMeasurementExponent                   0.000000     0.0      0.00
# SourceMeasurementUnit                       0.000000     0.0      0.00
# UnassignedInt1                              0.000000     0.0      0.00
# UnassignedInt2                              0.000000     0.0      0.00
#
#                                             50%       75%      max
# TRACE_SEQUENCE_LINE                     26411.5  39616.75  52822.0
# TRACE_SEQUENCE_FILE                     26411.5  39616.75  52822.0
# FieldRecord                              1383.0   1469.00   1554.0
# TraceNumber                                73.0    112.00    150.0
# EnergySourcePoint                           0.0      0.00      0.0
# CDP                                         0.0      0.00      0.0
# CDP_TRACE                                   0.0      0.00      0.0
# TraceIdentificationCode                     1.0      1.00      7.0
# NSummedTraces                               0.0      0.00      0.0
# NStackedTraces                              0.0      0.00      0.0
# DataUse                                     0.0      0.00      0.0
# offset                                      0.0      0.00      0.0
# ReceiverGroupElevation                      0.0      0.00      0.0
# SourceSurfaceElevation                      0.0      0.00      0.0
# SourceDepth                                 0.0      0.00      0.0
# ReceiverDatumElevation                      0.0      0.00      0.0
# SourceDatumElevation                        0.0      0.00      0.0
# SourceWaterDepth                            0.0      0.00      0.0
# GroupWaterDepth                             0.0      0.00      0.0
# ElevationScalar                           -10.0    -10.00    -10.0
# SourceGroupScalar                         -10.0    -10.00    -10.0
# SourceX                                     0.0      0.00      0.0
# SourceY                                     0.0      0.00      0.0
# GroupX                                      0.0      0.00      0.0
# GroupY                                      0.0      0.00      0.0
# CoordinateUnits                             0.0      0.00      0.0
# WeatheringVelocity                          0.0      0.00      0.0
# SubWeatheringVelocity                       0.0      0.00      0.0
# SourceUpholeTime                            0.0      0.00      0.0
# GroupUpholeTime                             0.0      0.00      0.0
# SourceStaticCorrection                      0.0      0.00      0.0
# GroupStaticCorrection                       0.0      0.00      0.0
# TotalStaticApplied                          0.0      0.00      0.0
# LagTimeA                                    0.0      0.00      0.0
# LagTimeB                                    0.0      0.00      0.0
# DelayRecordingTime                          0.0      0.00      0.0
# MuteTimeStart                               0.0      0.00      0.0
# MuteTimeEND                                 0.0      0.00      0.0
# TRACE_SAMPLE_COUNT                       2501.0   2501.00   2501.0
# TRACE_SAMPLE_INTERVAL                    2000.0   2000.00   2000.0
# GainType                                    0.0      0.00      0.0
# InstrumentGainConstant                      0.0      0.00      0.0
# InstrumentInitialGain                       0.0      0.00      0.0
# Correlated                                  0.0      0.00      0.0
# SweepFrequencyStart                         0.0      0.00      0.0
# SweepFrequencyEnd                           0.0      0.00      0.0
# SweepLength                                 0.0      0.00      0.0
# SweepType                                   0.0      0.00      0.0
# SweepTraceTaperLengthStart                  0.0      0.00      0.0
# SweepTraceTaperLengthEnd                    0.0      0.00      0.0
# TaperType                                   0.0      0.00      0.0
# AliasFilterFrequency                        0.0      0.00      0.0
# AliasFilterSlope                            0.0      0.00      0.0
# NotchFilterFrequency                        0.0      0.00      0.0
# NotchFilterSlope                            0.0      0.00      0.0
# LowCutFrequency                             0.0      0.00      0.0
# HighCutFrequency                            0.0      0.00      0.0
# LowCutSlope                                 0.0      0.00      0.0
# HighCutSlope                                0.0      0.00      0.0
# YearDataRecorded                           93.0     93.00     93.0
# DayOfYear                                  31.0     31.00     31.0
# HourOfDay                                   7.0      8.00      8.0
# MinuteOfHour                               30.0     45.00     59.0
# SecondOfMinute                             30.0     45.00     59.0
# TimeBaseCode                                0.0      0.00      0.0
# TraceWeightingFactor                        0.0      0.00      0.0
# GeophoneGroupNumberRoll1                    0.0      0.00      0.0
# GeophoneGroupNumberFirstTraceOrigField      0.0      0.00      0.0
# GeophoneGroupNumberLastTraceOrigField       0.0      0.00      0.0
# GapSize                                     0.0      0.00      0.0
# OverTravel                                  0.0      0.00      0.0
# CDP_X                                    1383.0   1469.00   1554.0
# CDP_Y                                      73.0    112.00    150.0
# INLINE_3D                                   0.0      0.00      0.0
# CROSSLINE_3D                                0.0      0.00      0.0
# ShotPoint                                   0.0      0.00      0.0
# ShotPointScalar                             0.0      0.00      0.0
# TraceValueMeasurementUnit                   0.0      0.00      0.0
# TransductionConstantMantissa                0.0      0.00      0.0
# TransductionConstantPower                   0.0      0.00      0.0
# TransductionUnit                            0.0      0.00      0.0
# TraceIdentifier                             0.0      0.00      0.0
# ScalarTraceHeader                           0.0      0.00      0.0
# SourceType                                  0.0      0.00    256.0
# SourceEnergyDirectionMantissa               0.0      0.00      0.0
# SourceEnergyDirectionExponent               0.0      0.00      0.0
# SourceMeasurementMantissa                   0.0      0.00      0.0
# SourceMeasurementExponent                   0.0      0.00      0.0
# SourceMeasurementUnit                       0.0      0.00      0.0
# UnassignedInt1                              0.0      0.00      0.0
# UnassignedInt2                              0.0      0.00      0.0

# %%
#from segysak.segy import segy_loader

#segy_file = segy_loader("E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy")  # substitua pelo nome real
#print(segy_file.shape)  # Deve mostrar algo como (n_traces, n_samples)

# %%
#scrape = segy_header_scrape(segy_file, partial_scan=None)

# %%
from segysak.segy import segy_header_scrape

scrape = segy_header_scrape("E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy", partial_scan=None)
# Out:
# Processing Chunks:   0%|          | 0.00/1.00 [00:00<?, ? trace-chunks/s]
# Reading header:   0%|          | 0.00/52.8k [00:00<?, ? traces/s]

# %%
scrape.columns
# Out:
# Index(['TRACE_SEQUENCE_LINE', 'TRACE_SEQUENCE_FILE', 'FieldRecord',
#        'TraceNumber', 'EnergySourcePoint', 'CDP', 'CDP_TRACE',
#        'TraceIdentificationCode', 'NSummedTraces', 'NStackedTraces', 'DataUse',
#        'offset', 'ReceiverGroupElevation', 'SourceSurfaceElevation',
#        'SourceDepth', 'ReceiverDatumElevation', 'SourceDatumElevation',
#        'SourceWaterDepth', 'GroupWaterDepth', 'ElevationScalar',
#        'SourceGroupScalar', 'SourceX', 'SourceY', 'GroupX', 'GroupY',
#        'CoordinateUnits', 'WeatheringVelocity', 'SubWeatheringVelocity',
#        'SourceUpholeTime', 'GroupUpholeTime', 'SourceStaticCorrection',
#        'GroupStaticCorrection', 'TotalStaticApplied', 'LagTimeA', 'LagTimeB',
#        'DelayRecordingTime', 'MuteTimeStart', 'MuteTimeEND',
#        'TRACE_SAMPLE_COUNT', 'TRACE_SAMPLE_INTERVAL', 'GainType',
#        'InstrumentGainConstant', 'InstrumentInitialGain', 'Correlated',
#        'SweepFrequencyStart', 'SweepFrequencyEnd', 'SweepLength', 'SweepType',
#        'SweepTraceTaperLengthStart', 'SweepTraceTaperLengthEnd', 'TaperType',
#        'AliasFilterFrequency', 'AliasFilterSlope', 'NotchFilterFrequency',
#        'NotchFilterSlope', 'LowCutFrequency', 'HighCutFrequency',
#        'LowCutSlope', 'HighCutSlope', 'YearDataRecorded', 'DayOfYear',
#        'HourOfDay', 'MinuteOfHour', 'SecondOfMinute', 'TimeBaseCode',
#        'TraceWeightingFactor', 'GeophoneGroupNumberRoll1',
#        'GeophoneGroupNumberFirstTraceOrigField',
#        'GeophoneGroupNumberLastTraceOrigField', 'GapSize', 'OverTravel',
#        'CDP_X', 'CDP_Y', 'INLINE_3D', 'CROSSLINE_3D', 'ShotPoint',
#        'ShotPointScalar', 'TraceValueMeasurementUnit',
#        'TransductionConstantMantissa', 'TransductionConstantPower',
#        'TransductionUnit', 'TraceIdentifier', 'ScalarTraceHeader',
#        'SourceType', 'SourceEnergyDirectionMantissa',
#        'SourceEnergyDirectionExponent', 'SourceMeasurementMantissa',
#        'SourceMeasurementExponent', 'SourceMeasurementUnit', 'UnassignedInt1',
#        'UnassignedInt2'],
#       dtype='object')

# %%
plot = scrape.hist(bins=25, figsize=(20, 20))
plt.tight_layout()
plt.show()

# %%
# Parâmetros fornecidos
dxch = 26.67     # Distância entre os canais (canal spacing)
lstr = 4000.0    # Comprimento do streamer
dxsh = 29.67     # Distância entre os tiros
d0 = 241.1       # Offset mínimo
n = 9            # Aqui é n = número do primeiro tiro - 1

# Número do primeiro tiro (fldr). Por exemplo, se o primeiro fldr é 100:
fldr_start = 10
sh0 = fldr_start  # ou: sh0 = n + 1

# Cálculos
nch = lstr / dxch
xcdp0 = ((nch - 1) * dxch) / 2 + (sh0 - 1) * dxsh
cdp0 = (2 * xcdp0) / dxch

# Exibir e salvar os resultados
params = [dxch, dxsh, d0, nch, sh0, xcdp0, cdp0]
print("dxch dxsh d0 nch sh0 xcdp0 cdp0")
print(" ".join([f"{p:.4f}" for p in params]))

# Escreve no arquivo 'params.in'
with open("params.in", "w") as f:
    f.write(" ".join([str(p) for p in params]) + "\n")
# Out:
# dxch dxsh d0 nch sh0 xcdp0 cdp0
# 26.6700 29.6700 241.1000 149.9813 10.0000 2253.6950 169.0060

# %%
from obspy.io.segy.core import _read_segy
import numpy as np

# Lê o arquivo SEGY
stream = _read_segy("E:/MATEUS_2025/02_trabalho/segy/247_Santos_part1c.sgy", unpack_trace_headers=True)

# Parâmetros de geometria
dxch = 26.67          # Distância entre canais
dxsh = 29.67          # Distância entre tiros
d0 = 241.1            # Offset inicial
lstr = 4000           # Comprimento do streamer
sh0 = 1555            # fldr inicial - 1
nch = int(lstr / dxch)

# Atualiza headers
for trace in stream.traces:
    header = trace.stats.segy.trace_header

    # Usa os nomes corretos do dicionário do cabeçalho
    fldr = header.original_field_record_number
    tracf = header.trace_number_within_the_original_field_record

    # Calcula geometria
    of = dxch * (tracf - 1) + d0
    xcdp = ((nch - tracf) * dxch) / 2 + (fldr - sh0) * dxsh
    cdp = int((2 * xcdp / dxch) + 1)
    sx = d0 + (nch - 1) * dxch + (fldr - sh0) * dxsh
    gx = sx - of

    # Atualiza os headers
    header.source_coordinate_x = int(sx)
    header.group_coordinate_x = int(gx)
    header.cdp = int(cdp)
    header.offset = int(of)

# Garante que o header textual termina com o padrão SEG-Y
#texthead = stream.textual_file_header.decode('ascii', errors='ignore')
#lines = texthead.splitlines()
#if len(lines) < 40:
    #lines += ['C{:02d} '.format(len(lines) + i + 1) + ' ' * 73 for i in range(40 - len(lines))]
#lines[39] = 'C40 END TEXTUAL HEADER'
#stream.textual_file_header = '\n'.join(lines).encode('ascii')

# Salva em novo arquivo
stream.write("E:/MATEUS_2025/02_trabalho/Dados_criados/caravelab_geom1.sgy", format="SEGY", data_encoding=5)
# Out:
# C:\Users\locfa\anaconda3\Lib\site-packages\obspy\io\segy\segy.py:362: SEGYInvalidTextualHeaderWarning: The end header mark in the textual header should be set as 'C40 END TEXTUAL HEADER' or as 'C40 END EBCDIC        ' for a fully valid SEG-Y file. It is set to 'C40 END ASCII         ' which will be written to the file. Please change it if you want a fully valid file.
#   warnings.warn(msg, SEGYInvalidTextualHeaderWarning)
